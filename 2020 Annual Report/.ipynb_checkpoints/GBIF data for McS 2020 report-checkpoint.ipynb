# %%
import pandas as pd
from zipfile import ZipFile

# %%
with ZipFile("dwca-gbif-guam-insects-2020-12-28.zip") as myzip:
    myzip.printdir()
    data = myzip.open("occurrence.txt")
# Out:
# File Name                                             Modified             Size
# occurrence.txt                                 2020-12-27 23:08:34     48256084
# verbatim.txt                                   2020-12-27 23:08:36     40074643
# multimedia.txt                                 2020-12-27 23:08:36       232912
# citations.txt                                  2020-12-27 23:08:36        10087
# dataset/a5262686-e9bc-45b4-8b4f-ec2d2321bb3b.xml 2020-12-27 23:08:36         3087
# dataset/ac9a4b1b-b3d2-4bb0-9ed3-0232012e96c2.xml 2020-12-27 23:08:36         4376
# dataset/daea9e8b-0c17-46ba-8d74-9990b408f14a.xml 2020-12-27 23:08:36         3398
# dataset/e4d3fc77-1d94-495b-96ff-3fe8b8f7a3bd.xml 2020-12-27 23:08:36         5048
# dataset/01fdde0a-a371-45b6-a6a2-5656d57e3280.xml 2020-12-27 23:08:36         2541
# dataset/10e44c48-0839-4a20-86d5-f0e23ae2e366.xml 2020-12-27 23:08:36         6955
# dataset/2356f899-6244-4bbb-aa33-50e29132e86a.xml 2020-12-27 23:08:36         5865
# ...

# %%
df = pd.read_csv(data,sep='\t',low_memory=False)
df
# Out:
#            gbifID  abstract accessRights  accrualMethod  accrualPeriodicity  \
# 0      3005255579       NaN          NaN            NaN                 NaN
# 1      3005250705       NaN          NaN            NaN                 NaN
# 2      3005244864       NaN          NaN            NaN                 NaN
# 3      3005238712       NaN          NaN            NaN                 NaN
# 4      3005230708       NaN          NaN            NaN                 NaN
# ...           ...       ...          ...            ...                 ...
# 18599   658519633       NaN          NaN            NaN                 NaN
# 18600   614987957       NaN          NaN            NaN                 NaN
# 18601   614987944       NaN          NaN            NaN                 NaN
# 18602   614986049       NaN          NaN            NaN                 NaN
# 18603   441007349       NaN          NaN            NaN                 NaN
#
# ...

# %%
df = df.dropna(how='all', axis=1)
df
# Out:
#            gbifID accessRights bibliographicCitation created       identifier  \
# 0      3005255579          NaN                   NaN     NaN         66367295
# 1      3005250705          NaN                   NaN     NaN         66461297
# 2      3005244864          NaN                   NaN     NaN         66545937
# 3      3005238712          NaN                   NaN     NaN         66462530
# 4      3005230708          NaN                   NaN     NaN         66455981
# ...           ...          ...                   ...     ...              ...
# 18599   658519633          NaN                   NaN     NaN              NaN
# 18600   614987957          NaN                   NaN     NaN              NaN
# 18601   614987944          NaN                   NaN     NaN              NaN
# 18602   614986049          NaN                   NaN     NaN              NaN
# 18603   441007349          NaN                   NaN     NaN  MZLU:ENT:251897
#
# ...

# %%
sorted(df.columns)
# Out:
# ['acceptedNameUsage',
#  'acceptedScientificName',
#  'acceptedTaxonKey',
#  'accessRights',
#  'associatedReferences',
#  'associatedSequences',
#  'associatedTaxa',
#  'basisOfRecord',
#  'bibliographicCitation',
#  'catalogNumber',
#  'class',
#  'classKey',
#  'collectionCode',
#  'collectionID',
#  'continent',
#  'coordinateUncertaintyInMeters',
#  'countryCode',
#  'county',
#  'created',
#  'dataGeneralizations',
#  'datasetID',
#  'datasetKey',
#  'datasetName',
#  'dateIdentified',
#  'day',
#  'decimalLatitude',
#  'decimalLongitude',
#  'depth',
#  'depthAccuracy',
#  'disposition',
#  'dynamicProperties',
#  'elevation',
#  'elevationAccuracy',
#  'endDayOfYear',
#  'eventDate',
#  'eventID',
#  'eventRemarks',
#  'eventTime',
#  'family',
#  'familyKey',
#  'fieldNotes',
#  'fieldNumber',
#  'gbifID',
#  'genericName',
#  'genus',
#  'genusKey',
#  'georeferenceProtocol',
#  'georeferenceRemarks',
#  'georeferenceSources',
#  'georeferenceVerificationStatus',
# ...

# %%
df[['order','family','genus','scientificName']].nunique()
# Out:
# order               16
# family             228
# genus              620
# scientificName    1035
# dtype: int64
