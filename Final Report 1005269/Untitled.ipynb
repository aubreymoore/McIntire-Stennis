# %%
import pandas as pd

# %%
# !ls *.csv
# Out:
# observations-48284.csv	observations-48300.csv

# %%
df = pd.read_csv('observations-48300.csv')

# %%
df
# Out:
#             id                          observed_on_string observed_on  \
# 0       488631                                  2010-10-16  2010-10-16
# 1       576028                         2013-07-16 16:00:31  2013-07-16
# 2       607666                                         NaN         NaN
# 3       848865                                  2014-08-26  2014-08-26
# 4       902778                                  2014-09-29  2014-09-29
# 5       902782                                         NaN         NaN
# 6       910638             2014-10-06 9:39:25 AM GMT+10:00  2014-10-06
# 7       956438             2014-10-13 1:05:26 PM GMT+10:00  2014-10-13
# 8       956446                                  2014-07-21  2014-07-21
# 9       956459             2014-10-13 1:53:37 PM GMT+10:00  2014-10-13
# 10     1020915            2014-10-16 11:32:34 AM GMT+10:00  2014-10-16
# 11     1034862             2014-10-24 5:47:32 PM GMT+10:00  2014-10-24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1328 entries, 0 to 1327
# Data columns (total 46 columns):
# id                                  1328 non-null int64
# observed_on_string                  1307 non-null object
# observed_on                         1297 non-null object
# time_observed_at                    928 non-null object
# time_zone                           1328 non-null object
# out_of_range                        0 non-null float64
# user_id                             1328 non-null int64
# user_login                          1328 non-null object
# created_at                          1328 non-null object
# updated_at                          1328 non-null object
# quality_grade                       1328 non-null object
# license                             673 non-null object
# url                                 1328 non-null object
# image_url                           1307 non-null object
# sound_url                           0 non-null float64
# ...

# %%
df = df[['scientific_name', 'description', 'place_guess']]

# %%
df[df['description'].str.contains("GPEP", na=False)]
# Out:
#            scientific_name                                        description  \
# 178          Oxya japonica  Grasshopper feeding on Heretria in GPEPP shade...
# 197  Xylosandrus compactus  ex stem of Serianthes nelsonii sapling growing...
# 297            Dysmicoccus  Photo by R, James McConnell, University of Gua...
# 302   Campsomeris annulata  Collected by Kavika at GPEP Nursery.\r\n\r\nma...
# 915            Eriophyidae  Eriophyid mites attacking <i>Tabernaemontana r...
# 948     Cephonodes armatus  Caterpillar brought in by Elen Ziobro.\r\n\r\n...
#
#                                            place_guess
# 178                         UOG Campus, Mangilao, Guam
# 197          GPEPP Nursery, UOG Campus, Mangilao, Guam
# 297          University of Guam Campus, Mangilao, Guam
# 302  GPEPP Nursery, Univeristy of Guam, Mangilao, Guam
# 915                      GPEPP nursery, Mangilao, Guam
# 948  GPEPP Nursery, University of Guam, Mangilao, Guam

# %%
df[df['place_guess'].str.contains("GPEP", na=False)]
# Out:
#              scientific_name  \
# 197    Xylosandrus compactus
# 198                      NaN
# 210              Tetranychus
# 222   Notogramma cimiciforme
# 302     Campsomeris annulata
# 915              Eriophyidae
# 916   Metaleurodicus cardini
# 927              Thalassodes
# 948       Cephonodes armatus
# 1013   Badamia exclamationis
# 1014           Daphnis nerii
#
#                                             description  \
# 197   ex stem of Serianthes nelsonii sapling growing...
# 198                      ex Serianthes nelsonii sapling
# 210   Spider mites attacking Serianthes nelsonii. Pr...
# 222   Fly collected from <i>Serianthes nelsonii</i> ...
# 302   Collected by Kavika at GPEP Nursery.\r\n\r\nma...
# 915   Eriophyid mites attacking <i>Tabernaemontana r...
# 916   ex <i>Psychotria hombroniana</i>, an endangere...
# 927   Images courtesy of Dr. James McConnell.\r\n\r\...
# 948   Caterpillar brought in by Elen Ziobro.\r\n\r\n...
# ...
